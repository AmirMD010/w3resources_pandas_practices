# %% [markdown]
# # Pandas Indexing practice Question. 1 to 26

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Collected from websites: https://www.w3resource.com/python-exercises/pandas/index/index.php

# %% [markdown]
# #Question 1-25

# %% [markdown]
# 1. Write a Pandas program to display the default index and set a column as an Index in a given dataframe.

# %%
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4'],
    't_id':['t1', 't2', 't3', 't4', 't5', 't6']})
df_index = df.set_index(['school_code'])
df_index
# Out:
#             class            name date_Of_Birth  weight  address t_id
# school_code
# s001            V  Alberto Franco    15/05/2002      35  street1   t1
# s002            V    Gino Mcneill    17/05/2002      32  street2   t2
# s003           VI     Ryan Parkes    16/02/1999      33  street3   t3
# s001           VI    Eesha Hinton    25/09/1998      30  street1   t4
# s002            V    Gino Mcneill    11/05/2002      31  street2   t5
# s004           VI    David Parkes    15/09/1997      32  street4   t6

# %% [markdown]
# 2. Write a Pandas program to create a multi Index frame using two columns and using an Index and a column.

# %%
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4'],
    't_id':['t1', 't2', 't3', 't4', 't5', 't6']})
df_multi_index = df.set_index(['t_id','school_code'])
df_multi_index
# Out:
#                  class            name date_Of_Birth  weight  address
# t_id school_code
# t1   s001            V  Alberto Franco    15/05/2002      35  street1
# t2   s002            V    Gino Mcneill    17/05/2002      32  street2
# t3   s003           VI     Ryan Parkes    16/02/1999      33  street3
# t4   s001           VI    Eesha Hinton    25/09/1998      30  street1
# t5   s002            V    Gino Mcneill    11/05/2002      31  street2
# t6   s004           VI    David Parkes    15/09/1997      32  street4

# %% [markdown]
# 3. Write a Pandas program to display the default index and set a column as an Index in a given dataframe and then reset the index.

# %%
df_index = df.set_index('t_id')
df_index.reset_index(inplace=True)
df_index
# Out:
#   t_id school_code class            name date_Of_Birth  weight  address
# 0   t1        s001     V  Alberto Franco    15/05/2002      35  street1
# 1   t2        s002     V    Gino Mcneill    17/05/2002      32  street2
# 2   t3        s003    VI     Ryan Parkes    16/02/1999      33  street3
# 3   t4        s001    VI    Eesha Hinton    25/09/1998      30  street1
# 4   t5        s002     V    Gino Mcneill    11/05/2002      31  street2
# 5   t6        s004    VI    David Parkes    15/09/1997      32  street4

# %% [markdown]
# 4. Write a Pandas program to create an index labels by using 64-bit integers, using floating-point numbers in a given dataframe.

# %%
df_int64 = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4'],
    't_id':['t1', 't2', 't3', 't4', 't5', 't6']}, index=[1,2,3,4,5,6])
print(df_int64.index)
df_float64 = (df_int64.index * 0.1)
df_float64
# Out:
# Index([1, 2, 3, 4, 5, 6], dtype='int64')
# Index([0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001], dtype='float64')

# %% [markdown]
# 6. Write a Pandas program to create a dataframe indexing by date and time.

# %%
df_daterange = pd.date_range(start='2015-1-1', freq='YE', periods=4)
dt_datetime = pd.DataFrame({'Sales':[100,200,300,400]}, index = df_daterange)
dt_datetime
# Out:
#             Sales
# 2015-12-31    100
# 2016-12-31    200
# 2017-12-31    300
# 2018-12-31    400

# %% [markdown]
# 7. Write a Pandas program to create a dataframe and set a title or name of the index column.

# %%
df_index_name = df.set_index('t_id')
df_index_name.index.name = "columnName"
df_index_name
# Out:
#            school_code class            name date_Of_Birth  weight  address
# columnName
# t1                s001     V  Alberto Franco    15/05/2002      35  street1
# t2                s002     V    Gino Mcneill    17/05/2002      32  street2
# t3                s003    VI     Ryan Parkes    16/02/1999      33  street3
# t4                s001    VI    Eesha Hinton    25/09/1998      30  street1
# t5                s002     V    Gino Mcneill    11/05/2002      31  street2
# t6                s004    VI    David Parkes    15/09/1997      32  street4

# %% [markdown]
# 8. Write a Pandas program to set value in a specific cell in a given dataframe using index.

# %%
#df.set_index('t_id', inplace=True)
df.at['t1','class'] = 'X'
df
# Out:
#    school_code class            name date_Of_Birth  weight  address t_id
# 0         s001     V  Alberto Franco    15/05/2002    35.0  street1   t1
# 1         s002     V    Gino Mcneill    17/05/2002    32.0  street2   t2
# 2         s003    VI     Ryan Parkes    16/02/1999    33.0  street3   t3
# 3         s001    VI    Eesha Hinton    25/09/1998    30.0  street1   t4
# 4         s002     V    Gino Mcneill    11/05/2002    31.0  street2   t5
# 5         s004    VI    David Parkes    15/09/1997    32.0  street4   t6
# t1         NaN     X             NaN           NaN     NaN      NaN  NaN

# %% [markdown]
# 9. Write a Pandas program to convert index of a given dataframe into a column.

# %%
df_index_column = df.reset_index(level=0)
df_index_column
# Out:
#   index school_code class            name date_Of_Birth  weight  address t_id
# 0     0        s001     V  Alberto Franco    15/05/2002    35.0  street1   t1
# 1     1        s002     V    Gino Mcneill    17/05/2002    32.0  street2   t2
# 2     2        s003    VI     Ryan Parkes    16/02/1999    33.0  street3   t3
# 3     3        s001    VI    Eesha Hinton    25/09/1998    30.0  street1   t4
# 4     4        s002     V    Gino Mcneill    11/05/2002    31.0  street2   t5
# 5     5        s004    VI    David Parkes    15/09/1997    32.0  street4   t6
# 6    t1         NaN     X             NaN           NaN     NaN      NaN  NaN

# %% [markdown]
# 10. Write a Pandas program to convert 1st and 3rd levels in the index into columns from a multiple level of index frame of a given dataframe.

# %%
df_multi_index_ = df.set_index(['school_code','class','t_id'])
df_multi_index_column = df_multi_index_.reset_index(level=['school_code','t_id'])
df_multi_index_column
# Out:
#       school_code t_id            name date_Of_Birth  weight  address
# class
# V            s001   t1  Alberto Franco    15/05/2002    35.0  street1
# V            s002   t2    Gino Mcneill    17/05/2002    32.0  street2
# VI           s003   t3     Ryan Parkes    16/02/1999    33.0  street3
# VI           s001   t4    Eesha Hinton    25/09/1998    30.0  street1
# V            s002   t5    Gino Mcneill    11/05/2002    31.0  street2
# VI           s004   t6    David Parkes    15/09/1997    32.0  street4
# X             NaN  NaN             NaN           NaN     NaN      NaN

# %% [markdown]
# 11. Write a Pandas program to check if a specified value exists in single and multiple column index dataframe.

# %%
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 32, 33, 30, 31, 32],
    't_id':  ['t1', 't2', 't3', 't4', 't5', 't6']}
     )

df_mult_index_column = df.set_index(['t_id','school_code','class'])
print('V' in df_mult_index_column.index.levels[2])
print('t1' in df_mult_index_column.index.levels[0])
print('t7' in df_mult_index_column.index.levels[2])
# Out:
# True
# True
# False

# %% [markdown]
# 12. Write a Pandas program to construct a series using the MultiIndex levels as the column and index.

# %%
sales_arrays = [['sale1', 'sale1', 'sale2', 'sale2', 'sale3', 'sale3', 'sale4', 'sale4'],
          ['city1', 'city2', 'city1', 'city2', 'city1', 'city2', 'city1', 'city2']]
sales_tuples = list(zip(*sales_arrays))
sales_index = pd.MultiIndex.from_tuples(sales_tuples, name=['sales','city'])
ds = pd.Series(np.random.randn(8),index=sales_index)
ds
# Out:
# sales  city
# sale1  city1    0.515256
#        city2   -1.611722
# sale2  city1    1.652348
#        city2   -1.242531
# sale3  city1   -0.619777
#        city2    1.336508
# sale4  city1   -0.701373
#        city2    0.393163
# dtype: float64

# %% [markdown]
# 13. Write a Pandas program to construct a DataFrame using the MultiIndex levels as the column and index.

# %%
sales_arrays = [['sale1', 'sale1', 'sale2', 'sale2', 'sale3', 'sale3', 'sale4', 'sale4'],
          ['city1', 'city2', 'city1', 'city2', 'city1', 'city2', 'city1', 'city2']]
sales_tuples = list(zip(*sales_arrays))
sales_index = pd.MultiIndex.from_tuples(sales_tuples, name=['sales','city'])
df = pd.DataFrame({'one':np.arange(8), 'two':np.random.randn(8), 'three':np.random.randn(8),'four':np.random.randn(8)},index=sales_index)
df
# Out:
#              one       two     three      four
# sales city
# sale1 city1    0  0.315264  1.275432  0.229045
#       city2    1 -0.402939  0.518992 -0.082057
# sale2 city1    2  1.240656 -1.012745 -1.721950
#       city2    3  1.333932  1.485100  0.363998
# sale3 city1    4 -0.966037 -1.496777 -1.694908
#       city2    5 -0.129054 -1.518556  0.003138
# sale4 city1    6 -0.167715 -0.886633 -0.931785
#       city2    7 -1.397865 -0.966312  0.742716

# %% [markdown]
# 14. Write a Pandas program to extract a single row, rows and a specific value from a MultiIndex levels DataFrame.

# %%
df.loc[('sale1','city1'),'two']
# Out:
# np.float64(0.3152640419572178)

# %% [markdown]
# 15. Write a Pandas program to rename names of columns and specific labels of the Main Index of the MultiIndex dataframe.

# %%
df.rename(columns={'one':'col1', 'two':'col2'},inplace=True)
df.rename(index={'city1':'CITY1'}, inplace=True)
df
# Out:
#              col1      col2     three      four
# sales city
# sale1 CITY1     0  0.315264  1.275432  0.229045
#       city2     1 -0.402939  0.518992 -0.082057
# sale2 CITY1     2  1.240656 -1.012745 -1.721950
#       city2     3  1.333932  1.485100  0.363998
# sale3 CITY1     4 -0.966037 -1.496777 -1.694908
#       city2     5 -0.129054 -1.518556  0.003138
# sale4 CITY1     6 -0.167715 -0.886633 -0.931785
#       city2     7 -1.397865 -0.966312  0.742716

# %% [markdown]
# 16. Write a Pandas program to sort a MultiIndex of a DataFrame. Also sort on various levels of index.

# %%
df_sort = df.sort_index(level=1)
df_sort
# Out:
#              col1      col2     three      four
# sales city
# sale1 CITY1     0  0.315264  1.275432  0.229045
# sale2 CITY1     2  1.240656 -1.012745 -1.721950
# sale3 CITY1     4 -0.966037 -1.496777 -1.694908
# sale4 CITY1     6 -0.167715 -0.886633 -0.931785
# sale1 city2     1 -0.402939  0.518992 -0.082057
# sale2 city2     3  1.333932  1.485100  0.363998
# sale3 city2     5 -0.129054 -1.518556  0.003138
# sale4 city2     7 -1.397865 -0.966312  0.742716

# %% [markdown]
# 17. Write a Pandas program to extract elements in the given positional indices along an axis of a dataframe.

# %%
print(df.take([1,3], axis=1))
# Out:
#                  col2      four
# sales city
# sale1 CITY1  0.315264  0.229045
#       city2 -0.402939 -0.082057
# sale2 CITY1  1.240656 -1.721950
#       city2  1.333932  0.363998
# sale3 CITY1 -0.966037 -1.694908
#       city2 -0.129054  0.003138
# sale4 CITY1 -0.167715 -0.931785
#       city2 -1.397865  0.742716

# %% [markdown]
# 18. Write a Pandas program to get the index of an element of a given Series.

# %%
ds = pd.Series(np.arange(1,8,2))
ds[ds==5].index[0]
# Out:
# np.int64(2)

# %% [markdown]
# 19. Write a Pandas program to select a specific row of given series/dataframe by integer index.

# %%
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 32, 33, 30, 31, 32]})

df.iloc[[1]]
# Out:
#   school_code class          name date_of_birth  weight
# 1        s002     V  Gino Mcneill    17/05/2002      32

# %% [markdown]
# 20. Write a Pandas program to find the indexes of rows of a specified value of a given column in a DataFrame.

# %%
df.index[df['school_code']=='s003'].tolist()
# Out:
# [2]

# %% [markdown]
# 21. Write a Pandas program to drop a index level from a multi-level column index of a dataframe.

# %%
cols = pd.MultiIndex.from_tuples([("a", "x"), ("a", "y"), ("a", "z")])
df = pd.DataFrame([[1,2,3], [3,4,5], [5,6,7]], columns=cols)
df.columns = df.columns.droplevel(level=1)
df
# Out:
#    a  a  a
# 0  1  2  3
# 1  3  4  5
# 2  5  6  7

# %% [markdown]
# 22. Write a Pandas program to insert a column at a specific index in a given DataFrame.

# %%
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, None, 33, 30, 31, None]},
     index = ['t1', 't2', 't3', 't4', 't5', 't6'])

new_col = [11,22,33,44,55,66]

df.insert(3,column='new column', value=new_col)
df
# Out:
#    school_code class            name  new column date_of_birth  weight
# t1        s001     V  Alberto Franco          11    15/05/2002    35.0
# t2        s002     V    Gino Mcneill          22    17/05/2002     NaN
# t3        s003    VI     Ryan Parkes          33    16/02/1999    33.0
# t4        s001    VI    Eesha Hinton          44    25/09/1998    30.0
# t5        s002     V    Gino Mcneill          55    11/05/2002    31.0
# t6        s004    VI    David Parkes          66    15/09/1997     NaN

# %% [markdown]
# 23. Write a Pandas program to print a DataFrame without index.

# %%
df.to_string(index=False)
# Out:
# 'school_code class           name  new column date_of_birth  weight\n       s001     V Alberto Franco          11    15/05/2002    35.0\n       s002     V   Gino Mcneill          22    17/05/2002     NaN\n       s003    VI    Ryan Parkes          33    16/02/1999    33.0\n       s001    VI   Eesha Hinton          44    25/09/1998    30.0\n       s002     V   Gino Mcneill          55    11/05/2002    31.0\n       s004    VI   David Parkes          66    15/09/1997     NaN'

# %% [markdown]
# 24. Write a Pandas program to find integer index of rows with missing data in a given dataframe.

# %%
index_rows = df[df.isnull().any(axis=1)].index.tolist()
index_rows
# Out:
# ['t2', 't6']

# %% [markdown]
# 25. Write a Pandas program to start index with different value rather than 0 in a given DataFrame.

# %%
df.index = range(100, 100 + len(df))
df
# Out:
#     school_code class            name  new column date_of_birth  weight
# 100        s001     V  Alberto Franco          11    15/05/2002    35.0
# 101        s002     V    Gino Mcneill          22    17/05/2002     NaN
# 102        s003    VI     Ryan Parkes          33    16/02/1999    33.0
# 103        s001    VI    Eesha Hinton          44    25/09/1998    30.0
# 104        s002     V    Gino Mcneill          55    11/05/2002    31.0
# 105        s004    VI    David Parkes          66    15/09/1997     NaN
